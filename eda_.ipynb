# %% [markdown]
# <a href="https://colab.research.google.com/github/urza3tar3/ai/blob/main/eda_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
fp = "../content/study_data.xlsx - gpa_norm.csv"

# %%
df = pd.read_csv(fp)
df.head(5)
# Out:
#   gender  h_score attended_uni                     major    gpa  \
# 0    ذكر     87.7          نعم  كلية الزراعة التكنولوجيا  90.00
# 1   أنثى     97.8          نعم         كلية علوم التأهيل   4.75
# 2   أنثى     81.3          نعم  كلية تكنولوجيا المعلومات   3.45
# 3    ذكر     78.0          نعم               كلية الحقوق   3.20
# 4    ذكر     76.2          نعم  كلية تكنولوجيا المعلومات   3.50
#
#   studied_abroad                uni_name work_field         employment_stat  \
# 0            نعم                    أخرى    الهندسة                   موظّف
# 1            نعم                    أخرى       الطب  عمل حرّ, عاطل عن العمل
# 2             لا        الجامعة الأردنية        NaN           عاطل عن العمل
# 3             لا  جامعة العلوم الاسلامية    التدريب                   موظّف
# 4            نعم        الجامعة الأردنية    التجارة                 عمل حرّ
#
#                                    form_source  age_c  gpa_norm  \
# ...

# %%
df.shape
df.dtypes
# Out:
# gender                 object
# h_score               float64
# attended_uni           object
# major                  object
# gpa                   float64
# studied_abroad         object
# uni_name               object
# work_field             object
# employment_stat        object
# form_source            object
# age_c                   int64
# gpa_norm              float64
# annual_income           int64
# gender_new            float64
# annual_income_new       int64
# studied_abroad_new    float64
# attended_uni_new      float64
# index                   int64
# dtype: object

# %%
df.sample(5)
# Out:
#     gender  h_score attended_uni                     major   gpa  \
# 131   أنثى    87.00          نعم  كلية الزراعة التكنولوجيا  2.75
# 304   أنثى    74.25          نعم  كلية تكنولوجيا المعلومات  2.60
# 18     ذكر    84.00           لا                       NaN   NaN
# 255   أنثى    92.70          نعم              كلية الصيدلة  3.36
# 348   أنثى    60.00           لا                       NaN   NaN
#
#     studied_abroad                            uni_name     work_field  \
# 131             لا  جامعة العلوم والتكنولوجيا الأردنية  مراكز الاتصال
# 304             لا                    الجامعة الأردنية            NaN
# 18             NaN                                 NaN        الأعمال
# 255            نعم                    الجامعة الأردنية            NaN
# 348            NaN                                 NaN            NaN
#
#     employment_stat form_source  age_c  gpa_norm  annual_income  gender_new  \
# ...

# %%
pd.isnull(df).nunique()
# Out:
# gender                2
# h_score               1
# attended_uni          2
# major                 2
# gpa                   2
# studied_abroad        2
# uni_name              2
# work_field            2
# employment_stat       2
# form_source           2
# age_c                 1
# gpa_norm              2
# annual_income         1
# gender_new            2
# annual_income_new     1
# studied_abroad_new    2
# attended_uni_new      2
# index                 1
# dtype: int64

# %%
tawjihi = df["gpa_norm"]
income = df["annual_income_new"]

# %%
plt.scatter(tawjihi , income,marker="x", c="black")

# %%
df.hist(figsize=(15,15))
plt.show()

# %%
df.describe()
# Out:
#           h_score         gpa       age_c    gpa_norm  annual_income  \
# count  396.000000  361.000000  396.000000  361.000000     396.000000
# mean    82.601263   29.226839   30.815657    0.772797    7556.272727
# std     10.407959   35.811461   11.908038    0.114320   13274.688260
# min     57.500000    0.200000   18.000000    0.050000       0.000000
# 25%     74.550000    3.000000   22.000000    0.700000     509.000000
# 50%     84.000000    3.500000   26.000000    0.770000    3600.000000
# 75%     91.000000   72.700000   38.000000    0.845000    8000.000000
# max    100.000000   98.000000   69.000000    1.000000  120000.000000
#
#        gender_new  annual_income_new  studied_abroad_new  attended_uni_new  \
# count  392.000000         396.000000          361.000000        394.000000
# mean     0.573980        8345.106061            0.121884          0.923858
# std      0.495129       13161.562854            0.327605          0.265563
# ...

# %%
df.describe(include='object')
# Out:
#        gender attended_uni         major studied_abroad          uni_name  \
# count     392          394           353            361               360
# unique      2            2            34              2                22
# top      أنثى          نعم  كلية الهندسة             لا  الجامعة الأردنية
# freq      225          364            74            317               155
#
#        work_field employment_stat  \
# count         304             375
# unique         19               9
# top       التدريس           موظّف
# freq           87             199
#
#                                               form_source
# count                                                  54
# unique                                                  7
# top     Social Media: Facebook/ Instagram/ Snapchat/ W...
# freq                                                   26

# %%
dff =df['annual_income_new']

# %%
   for tawjihi in dff.select_dtypes(include="object"):
    if dff[tawjihi].nunique() <= 7:
        sns.countplot(y=tawjihi, dff=dff)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-cd1294a1d8a2> in <module>
#       1 for tawjihi in dff.select_dtypes(include="object"):
#       2  if dff[tawjihi].nunique() <= 7:
# ----> 3      sns.countplot(y=tawjihi, dff=dff)
#       4      plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
# ...

# %%
df[gender].nunique()
# Out:
# 7

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df, cmap='RdBu_r', annot=True, vmax=1, vmin=-1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-093f7605192a> in <module>
#       1 plt.figure(figsize=(6,6))
# ----> 2 sns.heatmap(df, cmap='RdBu_r', annot=True, vmax=1, vmin=-1)
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...
